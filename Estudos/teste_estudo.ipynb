# %%
import pandas as pd

# %%
dados = ({
    'Nome':["Peixoto","Cabra-Peste","Junin","Rodolfo","Pitanga"],
    'Sobrenome':["Barroso","Chupisco", "Inverno", "Patati", "Patata"],
    'Idade':[12,13,15,11,17],
    'Altura':[2.20,1.85,1.62,1.55,2.10]
})
dados
# Out:
# {'Nome': ['Peixoto', 'Cabra-Peste', 'Junin', 'Rodolfo', 'Pitanga'],
#  'Sobrenome': ['Barroso', 'Chupisco', 'Inverno', 'Patati', 'Patata'],
#  'Idade': [12, 13, 15, 11, 17],
#  'Altura': [2.2, 1.85, 1.62, 1.55, 2.1]}

# %%
dados = pd.DataFrame(dados)
dados.head()
# Out:
#           Nome Sobrenome  Idade  Altura
# 0      Peixoto   Barroso     12    2.20
# 1  Cabra-Peste  Chupisco     13    1.85
# 2        Junin   Inverno     15    1.62
# 3      Rodolfo    Patati     11    1.55
# 4      Pitanga    Patata     17    2.10

# %%
dados.nlargest(5,'Altura')
# Out:
#           Nome Sobrenome  Idade  Altura
# 0      Peixoto   Barroso     12    2.20
# 4      Pitanga    Patata     17    2.10
# 1  Cabra-Peste  Chupisco     13    1.85
# 2        Junin   Inverno     15    1.62
# 3      Rodolfo    Patati     11    1.55

# %%
dados.nlargest(5, "Idade")
# Out:
#           Nome Sobrenome  Idade  Altura
# 4      Pitanga    Patata     17    2.10
# 2        Junin   Inverno     15    1.62
# 1  Cabra-Peste  Chupisco     13    1.85
# 0      Peixoto   Barroso     12    2.20
# 3      Rodolfo    Patati     11    1.55

# %%
dados.columns
# Out:
# Index(['Nome', 'Sobrenome', 'Idade', 'Altura'], dtype='object')

# %%
dados.dtypes
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1920034689.py in <cell line: 0>()
# ----> 1 dados.dtypes(int)
#
# TypeError: 'Series' object is not callable
