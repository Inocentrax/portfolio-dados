# %% [markdown]
# Tuplas possuem valores imutaveis dentro de parenteses e com virgulas, os parenteses podem ser omitidos

# %%
tupla = (4,5,6)
tupla
# Out:
# (4, 5, 6)

# %%
tup = 4,5,6
tup
# Out:
# (4, 5, 6)

# %% [markdown]
# Podemos converter qualquer iterador em tupla

# %%
strin_tupla = tuple("String")
strin_tupla
# Out:
# ('S', 't', 'r', 'i', 'n', 'g')

# %%
print(strin_tupla[0])
# Out:
# S

# %%
duas_tuplas = (1,2,3),(4,5,6)
duas_tuplas
# Out:
# ((1, 2, 3), (4, 5, 6))

# %%
duas_tuplas[0]
# Out:
# (1, 2, 3)

# %%
duas_tuplas[1]
# Out:
# (4, 5, 6)
