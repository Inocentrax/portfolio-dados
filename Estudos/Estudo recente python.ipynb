# %%
import pandas as pd

# %%
nivel_estudantil_idade = {"Escolaridade":["Ensino medio","Graduação","Pós-Graduação","Especialização"],
                          "Idade":[17,25,30,35]}

# %%
nivel_estudantil_idade = pd.DataFrame(nivel_estudantil_idade)
nivel_estudantil_idade
# Out:
#      Escolaridade  Idade
# 0    Ensino medio     17
# 1       Graduação     25
# 2   Pós-Graduação     30
# 3  Especialização     35

# %%
selecao1 = nivel_estudantil_idade[nivel_estudantil_idade["Idade"] == 17].sum()
selecao1
# Out:
# Escolaridade    Ensino medio
# Idade                     17
# dtype: object

# %%
nivel_estudantil_idade.loc[len(nivel_estudantil_idade)]={"Escolaridade":"Ensino Medio", "Idade":17}

# %%
nivel_estudantil_idade
# Out:
#      Escolaridade  Idade
# 0    Ensino medio     17
# 1       Graduação     25
# 2   Pós-Graduação     30
# 3  Especialização     35
# 4    Ensino Medio     17

# %%
nivel_estudantil_idade.drop(5, axis=0, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3914460355.py in <cell line: 0>()
# ----> 1 nivel_estudantil_idade.drop(5, axis=0, inplace=True)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
nivel_estudantil_idade
# Out:
#      Escolaridade  Idade
# 0    Ensino medio     17
# 1       Graduação     25
# 2   Pós-Graduação     30
# 3  Especialização     35
# 4    Ensino Medio     17

# %%
nivel_estudantil_idade.loc[len(nivel_estudantil_idade)] = {"Escolaridade": "Mestrado", "Idade":35}

# %%
nivel_estudantil_idade.drop(4,axis=0, inplace=True)

# %%
nivel_estudantil_idade
# Out:
#      Escolaridade  Idade
# 0    Ensino medio     17
# 1       Graduação     25
# 2   Pós-Graduação     30
# 3  Especialização     35
# 5        Mestrado     35

# %%
selecao2=nivel_estudantil_idade["Idade"]==35
selecao2
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 5     True
# Name: Idade, dtype: bool

# %%
nivel_estudantil_idade.query("Idade==35")
# Out:
#      Escolaridade  Idade
# 3  Especialização     35
# 5        Mestrado     35

# %%
nivel_estudantil_idade.query('Escolaridade == "Mestrado"')
# Out:
#   Escolaridade  Idade
# 5     Mestrado     35

# %%
nivel_estudantil_idade.query('Escolaridade == "Ensino medio" & Idade==17')
# Out:
#    Escolaridade  Idade
# 0  Ensino medio     17

# %%
nivel_estudantil_idade.loc[len(nivel_estudantil_idade)] = {"Escolaridade":"Ensino medio", "Idade":17}

# %%
nivel_estudantil_idade
# Out:
#      Escolaridade  Idade
# 0    Ensino medio     17
# 1       Graduação     25
# 2   Pós-Graduação     30
# 3  Especialização     35
# 5    Ensino medio     17

# %%
nivel_estudantil_idade.query('Escolaridade=="Ensino medio"')
# Out:
#    Escolaridade  Idade
# 0  Ensino medio     17
# 5  Ensino medio     17

# %%
nivel_estudantil_idade.loc[len(nivel_estudantil_idade)] = {"Escolaridade":"Ensino medio", "Idade":19}

# %%
nivel_estudantil_idade
# Out:
#      Escolaridade  Idade
# 0    Ensino medio     17
# 1       Graduação     25
# 2   Pós-Graduação     30
# 3  Especialização     35
# 5    Ensino medio     19

# %%
nivel_estudantil_idade.query('Escolaridade=="Ensino medio" & Idade==19')
# Out:
#    Escolaridade  Idade
# 5  Ensino medio     19
