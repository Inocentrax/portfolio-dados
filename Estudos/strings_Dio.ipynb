# %%
curso = '   Python '

# %%
curso.lower()
# Out:
# '   python '

# %%
curso.upper()
# Out:
# '   PYTHON '

# %%
curso.title()
# Out:
# '   Python '

# %%
curso.strip()
# Out:
# 'Python'

# %%
curso.lstrip()
# Out:
# 'Python '

# %%
curso.rstrip()
# Out:
# '   Python'

# %%
print(curso)
# Out:
#    Python

# %%
curso= curso.strip()
print(curso)
# Out:
# Python

# %%
print(curso.center(10,'#'))
# Out:
# ##Python##

# %%
print('.'.join(curso))
# Out:
# P.y.t.h.o.n
