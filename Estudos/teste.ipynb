# %%
import pandas as pd

# %%
dados = {"Nome":["Ana", "Pedro", "Paulo", "Matheus"],
         "Idade":[25,28,24,26],
         "Cidade":["São Paulo", "Curitiba", "Rio de Janeiro", "São Sebastião"]}

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Nome    5 non-null      object
#  1   Sexo    5 non-null      object
#  2   Idade   5 non-null      int64
#  3   Cidade  5 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 200.0+ bytes

# %%
dados = pd.DataFrame(dados)
dados
# Out:
#       Nome  Idade          Cidade
# 0      Ana     25       São Paulo
# 1    Pedro     28        Curitiba
# 2    Paulo     24  Rio de Janeiro
# 3  Matheus     26   São Sebastião

# %%
dados.head(2)
# Out:
#     Nome  Idade     Cidade
# 0    Ana     25  São Paulo
# 1  Pedro     28   Curitiba

# %%
dados.tail(2)
# Out:
#       Nome  Idade          Cidade
# 2    Paulo     24  Rio de Janeiro
# 3  Matheus     26   São Sebastião

# %%
dados["Cidade"]
# Out:
# 0         São Paulo
# 1          Curitiba
# 2    Rio de Janeiro
# 3     São Sebastião
# Name: Cidade, dtype: object

# %%
dados.isnull().sum()
# Out:
# Nome      0
# Idade     0
# Cidade    0
# dtype: int64

# %%
dados.loc[len(dados)] = ["Tais", 26, "São sebastião"]

# %%
dados
# Out:
#       Nome  Idade          Cidade
# 0      Ana     25       São Paulo
# 1    Pedro     28        Curitiba
# 2    Paulo     24  Rio de Janeiro
# 3  Matheus     26   São Sebastião
# 4     Tais     26   São sebastião

# %%
dados
# Out:
#       Nome  Idade          Cidade
# 0      Ana     25       São Paulo
# 1    Pedro     28        Curitiba
# 2    Paulo     24  Rio de Janeiro
# 3  Matheus     26   São Sebastião
# 4     Tais     26   São sebastião

# %%
dados.insert(1, "Sexo", ["Feminino","Masculino", "Masculino","Masculino","Feminino"])

# %%
dados
# Out:
#       Nome       Sexo  Idade          Cidade
# 0      Ana   Feminino     25       São Paulo
# 1    Pedro  Masculino     28        Curitiba
# 2    Paulo  Masculino     24  Rio de Janeiro
# 3  Matheus  Masculino     26   São Sebastião
# 4     Tais   Feminino     26   São sebastião

# %%
dados.insert(4, "Sigla", ["SP","CU","RJ","BSB","BSB"])

# %%
dados
# Out:
#       Nome       Sexo  Idade          Cidade Sigla
# 0      Ana   Feminino     25       São Paulo    SP
# 1    Pedro  Masculino     28        Curitiba    CU
# 2    Paulo  Masculino     24  Rio de Janeiro    RJ
# 3  Matheus  Masculino     26   São Sebastião   BSB
# 4     Tais   Feminino     26   São sebastião   BSB

# %%
dados.drop("Sigla", axis=1, inplace=True)

# %%
dados
# Out:
#       Nome       Sexo  Idade          Cidade
# 0      Ana   Feminino     25       São Paulo
# 1    Pedro  Masculino     28        Curitiba
# 2    Paulo  Masculino     24  Rio de Janeiro
# 3  Matheus  Masculino     26   São Sebastião
# 4     Tais   Feminino     26   São sebastião

# %%
dados.boxplot("Idade", by="Sexo")
# Out:
# <Axes: title={'center': 'Idade'}, xlabel='Sexo'>
